# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 from sqlalchemy import create_engine
#       3 # ต้องติดตั้ง sqlalchemy และมีการเชื่อมต่อสำเร็จจากขั้นตอนที่ 1 (ตัวแปร conn)
#       4
#       5 # --- 1. ตรวจสอบการเชื่อมต่อ ---
# ----> 6 if conn is None:
#       7     print("❌ ไม่สามารถดำเนินการต่อได้ กรุณาตรวจสอบการเชื่อมต่อฐานข้อมูลในขั้นตอนที่ 1")
#       8 else:
#
# NameError: name 'conn' is not defined

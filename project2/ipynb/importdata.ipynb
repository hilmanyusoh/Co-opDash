# %%
# ===============================
# 1) import library ที่จำเป็น
# ===============================
import pandas as pd
from sqlalchemy import create_engine


# ===============================
# 2) ตั้งค่าการเชื่อมต่อ PostgreSQL
# ===============================
DB_USER = "myuser"
DB_PASSWORD = "mypassword"
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "mydatabase"

DATABASE_URL = (
    f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}"
    f"@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

engine = create_engine(DATABASE_URL)


# ===============================
# 3) อ่านไฟล์ CSV
# ===============================
CSV_PATH = "/Users/hilmanyusoh/Desktop/Co-opDash/project2/data/members.csv"

df = pd.read_csv(CSV_PATH)

# %%
# ดูข้อมูลตัวอย่าง
df.head()
# Out:
#    Member_ID  Branch_code    Prefix First_name    Surname    Birthday  \
# 0     100456            1       นาย      สมชาย       ใจดี  1990-05-15
# 1     201321            2    นางสาว   สุภาภรณ์  รุ่งเรือง  1985-11-20
# 2     350789            3       นาง      วนิดา     แก้วใส  1978-03-01
# 3     498112            4       นาย    พงษ์เทพ     มั่นคง  2000-07-28
# 4     524670            5  นายแพทย์     อนันต์  ชื่นจิตต์  1970-12-05
#
#   Registration_date Approval_date         Career   Income address  Group_id  \
# 0        2023-01-10    2023-01-15  พนักงานบริษัท   35,000  123/45         1
# 1        2023-02-20    2023-02-25            ครู   28,000    88/9         5
# 2        2023-03-05    2023-03-10         ค้าขาย   45,000      47        10
# 3        2023-04-12    2023-04-18       นักศึกษา   10,000    22/5         3
# 4        2023-05-01    2023-05-05          แพทย์  120,000    99/9         2
#
#     Village Subdistrict        District       Province  postal_code
# 0   มิตรภาพ       บางนา           บางนา  กรุงเทพมหานคร        10260
# 1  สุขสันต์     ท่าศาลา         ท่าศาลา  นครศรีธรรมราช        80160
# 2  ศิริมงคล     บ้านดู่   เมืองเชียงราย       เชียงราย        57100
# 3   เกษมสุข        คูคต         ลำลูกกา       ปทุมธานี        12150
# 4  ราชพฤกษ์       สุเทพ  เมืองเชียงใหม่      เชียงใหม่        50200

# %%
df.tail()
# Out:
#     Member_ID  Branch_code  Prefix First_name   Surname    Birthday  \
# 60     677890            1     นาย       เดชา     ฟ้าใส  1993-10-10
# 61     788900            2  นางสาว      อัมรา    แสงทอง  1987-11-29
# 62     899010            3     นาย     บุญส่ง    ถึงที่  1961-01-01
# 63     900120            4     นาง   มณีรัตน์  เพชรพลอย  1976-03-03
# 64     111230            5     นาย      พรชัย     มีลาภ  1990-05-05
#
#    Registration_date Approval_date           Career   Income address  \
# 60        2028-03-27    2028-04-01    ช่างซ่อมบำรุง   24,000      43
# 61        2028-05-01    2028-05-06       มัคคุเทศก์   30,000    44/4
# 62        2028-06-12    2028-06-17     พนักงานขับรถ   18,000      45
# 63        2028-07-25    2028-07-30  นักธุรกิจอัญมณี  100,000      46
# 64        2028-08-08    2028-08-13     ผู้ประกอบการ   85,000      47
#
#     Group_id     Village         Subdistrict            District  \
# 60         9     ซ่อมแซม         เมืองลพบุรี         เมืองลพบุรี
# 61        11  ท่องเที่ยว   เมืองสุราษฎร์ธานี   เมืองสุราษฎร์ธานี
# 62         2     เดินทาง  เมืองนครศรีธรรมราช  เมืองนครศรีธรรมราช
# 63         4    เจียระไน              บางรัก              บางรัก
# 64         6      ร่ำรวย    เมืองอุบลราชธานี    เมืองอุบลราชธานี
#
#          Province  postal_code
# 60         ลพบุรี        15000
# 61   สุราษฎร์ธานี        84000
# 62  นครศรีธรรมราช        80000
# 63  กรุงเทพมหานคร        10500
# 64    อุบลราชธานี        34000
